# %% [markdown]
# <a href="https://colab.research.google.com/github/XLaughs/TESTREPO/blob/main/Phone_Model_Price_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path = "/content/drive/MyDrive/prices.csv"
df = pd.read_csv(path)

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('bmh')
df = pd.read_csv('prices.csv')

# All Brands
x = df['Model']
y = df['Price']

# Specified Brands
# specified = df.loc[df['Company'] == 'Samsung']
# x = specified['Model']
# y = specified['Price']

# Bar chart
# plt.xlabel('Model', fontsize=18)
# plt.ylabel('Price($)', fontsize=16)
# plt.bar(x, y)


# Line Graph
# plt.xlabel('Model', fontsize=18)
# plt.ylabel('Price($)', fontsize=16)
# plt.scatter(x, y)
# plt.plot(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('bmh')
df = pd.read_csv('prices.csv')

# All Brands
x = df['Model']
y = df['Price']

# Specified Brands
# specified = df.loc[df['Company'] == 'Samsung']
# x = specified['Model']
# y = specified['Price']

# Bar chart
# plt.xlabel('Model', fontsize=18)
# plt.ylabel('Price($)', fontsize=16)
# plt.bar(x, y)


# Line Graph
# plt.xlabel('Model', fontsize=18)
# plt.ylabel('Price($)', fontsize=16)
# plt.scatter(x, y)
# plt.plot(x, y)

plt.show()

# %%
import os

# Get the current working directory
cwd = os.getcwd()

# Print the current working directory
print(f"Current working directory: {cwd}")

# Check if the file exists in the current working directory
if os.path.exists(os.path.join(cwd, 'prices.csv')):
    print("File 'prices.csv' exists in the current working directory.")
else:
    print("File 'prices.csv' does not exist in the current working directory.")
# Out:
# Current working directory: /content
# File 'prices.csv' does not exist in the current working directory.

# %%
path = "/content/drive/MyDrive/prices.csv"
df = pd.read_csv(path)

# %%
# !cp /content/drive/MyDrive/prices.csv .

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('bmh')
df = pd.read_csv('prices.csv')

# All Brands
x = df['Model']
y = df['Price']

# Specified Brands
# specified = df.loc[df['Company'] == 'Samsung']
# x = specified['Model']
# y = specified['Price']

# Bar chart
# plt.xlabel('Model', fontsize=18)
# plt.ylabel('Price($)', fontsize=16)
# plt.bar(x, y)

# Bar chart
plt.pie(y, labels=x, radius=1.2,autopct='%0.01f%%', shadow=True, explode=[.05,.2,.05,.2,.05,.2,.05])

# Line Graph
# plt.xlabel('Model', fontsize=18)
# plt.ylabel('Price($)', fontsize=16)
# plt.scatter(x, y)
# plt.plot(x, y)

plt.show()
